# %%
from os import path
from os import listdir

import pandas as pd
import scipy.sparse as sp
import anndata

# %% [markdown]
# Download files to `data/tasic_2018` folder:
#
# Main page: https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE115746
#
# - https://ftp.ncbi.nlm.nih.gov/geo/series/GSE115nnn/GSE115746/suppl/GSE115746%5Fcells%5Fexon%5Fcounts%2Ecsv%2Egz
# - https://ftp.ncbi.nlm.nih.gov/geo/series/GSE115nnn/GSE115746/suppl/GSE115746%5Fcomplete%5Fmetadata%5F28706%2Dcells%2Ecsv%2Egz
#
# Download cluster annotations for clusters
# https://raw.githubusercontent.com/berenslab/rna-seq-tsne/master/data/tasic-sample_heatmap_plot_data.csv

# %%
data_path = path.join("..", "..", "data", "tasic_2018")

# %%
listdir(data_path)
# Out:
# ['GSE115746_cells_exon_counts.csv.gz',
#  'tasic-sample_heatmap_plot_data.csv',
#  'GSE115746_complete_metadata_28706-cells.csv.gz']

# %%
# %time data = pd.read_csv(path.join(data_path, "GSE115746_cells_exon_counts.csv.gz"), index_col=0)
# Out:
# CPU times: user 6min 22s, sys: 14.9 s, total: 6min 37s
# Wall time: 6min 37s

# %%
data.head()
# Out:
#                F2S4_150422_002_A01  F2S4_150422_002_B01  F2S4_150422_002_C01  \
# 0610005C13Rik                    0                    0                    0
# 0610006L08Rik                    0                    0                    0
# 0610007P14Rik                   95                   48                  101
# 0610009B22Rik                   68                   47                   43
# 0610009E02Rik                    0                    0                   11
#
#                F2S4_150422_002_D01  F2S4_150422_002_E01  F2S4_150422_002_F01  \
# 0610005C13Rik                    0                    0                    0
# 0610006L08Rik                    0                    0                    0
# 0610007P14Rik                   51                   36                  128
# 0610009B22Rik                   42                   58                   14
# 0610009E02Rik                    0                    0                    1
#
#                F2S4_150422_002_G01  F2S4_150422_002_H01  F2S4_150427_001_A01  \
# 0610005C13Rik                    0                    0                    0
# 0610006L08Rik                    0                    0                    0
# 0610007P14Rik                  126                  102                   64
# 0610009B22Rik                   27                   68                   19
# 0610009E02Rik                    0                    0                    2
#
#                F2S4_150427_001_B01         ...           F1S4_180124_316_G01  \
# 0610005C13Rik                    0         ...                             0
# 0610006L08Rik                    0         ...                             0
# 0610007P14Rik                   75         ...                           105
# 0610009B22Rik                   83         ...                            41
# 0610009E02Rik                    0         ...                             0
#
#                F1S4_180124_316_H01  F1S4_180124_317_A01  F1S4_180124_317_B01  \
# 0610005C13Rik                    0                    0                   25
# 0610006L08Rik                    0                    0                    0
# 0610007P14Rik                  139                  103                  205
# 0610009B22Rik                   86                  271                  118
# 0610009E02Rik                    0                    0                    0
#
#                F1S4_180124_317_C01  F1S4_180124_317_D01  F1S4_180124_317_E01  \
# 0610005C13Rik                    0                    0                    0
# 0610006L08Rik                    0                    0                    0
# 0610007P14Rik                   88                  172                   27
# 0610009B22Rik                  101                  174                  102
# 0610009E02Rik                    0                    0                    0
#
#                F1S4_180124_317_F01  F1S4_180124_317_G01  F1S4_180124_317_H01
# 0610005C13Rik                    0                    0                    0
# 0610006L08Rik                    0                    0                    0
# 0610007P14Rik                  108                   23                  168
# 0610009B22Rik                  121                  111                  119
# 0610009E02Rik                    0                    0                    7
#
# [5 rows x 23178 columns]

# %%
data.shape
# Out:
# (45768, 23178)

# %%
# %time metadata = pd.read_csv(path.join(data_path, "GSE115746_complete_metadata_28706-cells.csv.gz"), index_col=0)
# Out:
# CPU times: user 256 ms, sys: 36 ms, total: 292 ms
# Wall time: 292 ms

# %%
metadata.head()
# Out:
#                                    title  \
# sample_name
# F0S4_150820_019_A01  F0S4_150820_019_A01
# F0S4_150820_019_B01  F0S4_150820_019_B01
# F0S4_150820_019_C01  F0S4_150820_019_C01
# F0S4_150820_019_D01  F0S4_150820_019_D01
# F0S4_150820_019_E01  F0S4_150820_019_E01
#
#                                                           source_name  \
# sample_name
# F0S4_150820_019_A01                           Control: 1E-8 ERCC MIX1
# F0S4_150820_019_B01                      Control: No Template Control
# F0S4_150820_019_C01                           Control: 1E-8 ERCC MIX1
# F0S4_150820_019_D01                      Control: No Template Control
# F0S4_150820_019_E01  Control: 10pg Zyagen Mouse Whole Brain Total RNA
#
#                     organism donor_id donor_sex donor_genotype injection_type  \
# sample_name
# F0S4_150820_019_A01  Control      NaN       NaN            NaN            NaN
# F0S4_150820_019_B01  Control      NaN       NaN            NaN            NaN
# F0S4_150820_019_C01  Control      NaN       NaN            NaN            NaN
# F0S4_150820_019_D01  Control      NaN       NaN            NaN            NaN
# F0S4_150820_019_E01  Control      NaN       NaN            NaN            NaN
#
#                     injection_target injected_material dissected_region  \
# sample_name
# F0S4_150820_019_A01              NaN               NaN              NaN
# F0S4_150820_019_B01              NaN               NaN              NaN
# F0S4_150820_019_C01              NaN               NaN              NaN
# F0S4_150820_019_D01              NaN               NaN              NaN
# F0S4_150820_019_E01              NaN               NaN              NaN
#
#                                            ...                          \
# sample_name                                ...
# F0S4_150820_019_A01                        ...
# F0S4_150820_019_B01                        ...
# F0S4_150820_019_C01                        ...
# F0S4_150820_019_D01                        ...
# F0S4_150820_019_E01                        ...
#
#                     sequencing_tube sequencing_batch sequencing_qc_pass_fail  \
# sample_name
# F0S4_150820_019_A01        LS-14690      R8S4-160203                    Pass
# F0S4_150820_019_B01        LS-14690      R8S4-160203                    Pass
# F0S4_150820_019_C01        LS-14690      R8S4-160203                    Pass
# F0S4_150820_019_D01        LS-14690      R8S4-160203                    Pass
# F0S4_150820_019_E01        LS-14690      R8S4-160203                    Pass
#
#                         cell_class cell_subclass cell_cluster   molecule  \
# sample_name
# F0S4_150820_019_A01           ERCC           NaN          NaN       ERCC
# F0S4_150820_019_B01            NTC           NaN          NaN  Total RNA
# F0S4_150820_019_C01           ERCC           NaN          NaN       ERCC
# F0S4_150820_019_D01            NTC           NaN          NaN  Total RNA
# F0S4_150820_019_E01  MouseWholeRNA           NaN          NaN  Total RNA
#
#                         SRA_Run  GEO_Sample  \
# sample_name
# F0S4_150820_019_A01  SRR7322881  GSM3189899
# F0S4_150820_019_B01  SRR7323629  GSM3189901
# F0S4_150820_019_C01  SRR7322992  GSM3189899
# F0S4_150820_019_D01  SRR7323740  GSM3189901
# F0S4_150820_019_E01  SRR7321958  GSM3189897
#
#                                                       GEO_Sample_Title
# sample_name
# F0S4_150820_019_A01                          Control: 1E-8 ERCC MIX1_1
# F0S4_150820_019_B01                     Control: No Template Control_1
# F0S4_150820_019_C01                          Control: 1E-8 ERCC MIX1_1
# F0S4_150820_019_D01                     Control: No Template Control_1
# F0S4_150820_019_E01  Control: 10pg Zyagen Mouse Whole Brain Total R...
#
# [5 rows x 24 columns]

# %%
x = sp.csr_matrix(data.values)
x
# Out:
# <45768x23178 sparse matrix of type '<class 'numpy.longlong'>'
# 	with 214290227 stored elements in Compressed Sparse Row format>

# %%
adata = anndata.AnnData(
    x.T,
    uns={"name": "tasic_2018", "year": 2018, "organism": "mouse", "tissue": "brain"},
    var={"var_names": data.index.values},
    obs={
        "obs_names": data.columns.values,
        "cell_class": metadata["cell_class"].astype(str),
        "batch": metadata["source_name"].astype(str),
    },
)
adata
# Out:
# AnnData object with n_obs × n_vars = 23178 × 45768
#     obs: 'cell_class', 'batch'
#     uns: 'name', 'year', 'organism', 'tissue'

# %%
adata.write_h5ad(path.join("..", "..", "data", "h5ad", "tasic_2018.h5ad"))
# Out:
# ... storing 'cell_class' as categorical
# ... storing 'batch' as categorical
